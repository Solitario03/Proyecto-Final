# %% [markdown]
# # Extracción y Procesamiento de Información Bibliográfica desde APIs Abiertas
# Este notebook tiene como objetivo extraer, procesar y estructurar información bibliográfica proveniente de distintas APIs abiertas relacionadas con libros y publicaciones académicas.
# A partir de consultas específicas, se obtienen datos relevantes como título, autor, año de publicación, editorial y DOI, los cuales son posteriormente almacenados en formato JSON y CSV para su análisis o reutilización.
#
# El flujo de trabajo sigue un enfoque típico de ETL (Extract, Transform, Load), separando claramente los datos crudos (raw) de los datos procesados (processed).

# %% [markdown]
# ## APIs utilizadas
#
# En este proyecto se emplean tres APIs públicas ampliamente utilizadas en el ámbito académico

# %% [markdown]
# ## Open Library API
# Proporciona información sobre libros, autores y fechas de publicación.

# %% [markdown]
# https://openlibrary.org/

# %% [markdown]
# ## OpenAlex API
# Ofrece datos académicos estructurados, permitiendo filtrar por tipo de publicación como libros.

# %% [markdown]
# https://api.openalex.org/works

# %% [markdown]
# ## Crossref API
# Brinda metadatos bibliográficos confiables, incluyendo editoriales y DOI.

# %% [markdown]
# https://api.crossref.org/works

# %% [markdown]
# ### 📘 Descarga de información desde la Open Library API
#
# Este código permite extraer información bibliográfica desde la **API de Open Library** a partir de un término de búsqueda definido por el usuario. Los datos obtenidos corresponden a libros relacionados con la consulta realizada y se almacenan en formato **JSON** para su posterior análisis.
#
# En primer lugar, se importan las librerías necesarias para realizar solicitudes HTTP, manipular datos en formato JSON y gestionar directorios del sistema. Luego, se define la función `descargar_openlibrary`, la cual recibe como parámetro una cadena de texto que representa el término de búsqueda.
#
# La función crea automáticamente la carpeta `data/raw` si esta no existe, asegurando una correcta organización de los datos crudos. Posteriormente, se construye la URL de consulta hacia la API incorporando el término de búsqueda y se realiza una solicitud GET para obtener los resultados.
#
# La respuesta de la API se convierte a formato JSON y se guarda en el archivo `openlibrary.json`, utilizando codificación UTF-8 para preservar caracteres especiales y una estructura legible. Finalmente, se muestra un mensaje de confirmación indicando que el archivo fue guardado correctamente.
#
# Este proceso representa la etapa de **extracción de datos** dentro del flujo ETL del proyecto.

# %%
import os
os.makedirs("data/raw", exist_ok=True)

# %%
import requests
import json
import os

def descargar_openlibrary(query):
    # Crear carpetas si no existen
    os.makedirs("data/raw", exist_ok=True)
    
    url = f"https://openlibrary.org/search.json?q={query}"
    resp = requests.get(url)
    data = resp.json()
    
    with open("data/raw/openlibrary.json", "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

    print("Archivo openlibrary.json guardado correctamente")

descargar_openlibrary("python libros")
# Out:
# Archivo openlibrary.json guardado correctamente

# %% [markdown]
# ### Conversion a csv

# %%
import json
import pandas as pd
import os

# Asegurar carpeta processed
os.makedirs("data/processed", exist_ok=True)

with open("data/raw/openlibrary.json", encoding="utf-8") as f:
    data = json.load(f)

libros = []

for libro in data["docs"][:100]:  # primeros 100 libros
    libros.append({
        "titulo": libro.get("title"),
        "autor": ", ".join(libro.get("author_name", [])) if "author_name" in libro else None,
        "anio_publicacion": libro.get("first_publish_year")
    })

df = pd.DataFrame(libros)
df.to_csv("data/processed/openlibrary.csv", index=False, encoding="utf-8")

df.head()
# Out:
#                                   titulo  \
# 0  Pythons' Autobiography by the Pythons
# 1                El gran libro de Python
# 2         Aprende a programar con PYTHON
# 3    PYTHON. Curso práctico de formación
# 4     PYTHON 3 al descubierto 2º Edición
#
#                                                autor  anio_publicacion
# 0  Monty Python, Graham Chapman, John Cleese, Ter...              2003
# 1                        Marco Buttu, EDIZIONI LSWR               2016
# 2                          José Dimas Luján Castillo              2019
# 3                           Juan Carlos Orós Cabello              2022
# 4                           Arturo Fernández Montoro              2013

# %% [markdown]
# ### 📗 Descarga de información desde la OpenAlex API
#
# Este código se encarga de extraer información bibliográfica desde la **API de OpenAlex**, enfocándose específicamente en publicaciones de tipo **libro** relacionadas con un término de búsqueda determinado.
#
# En primer lugar, se importan las librerías necesarias para realizar solicitudes HTTP, manipular datos en formato JSON y gestionar la creación de directorios. A continuación, se define la función `descargar_openalex`, la cual recibe como parámetro una cadena de texto que representa el término de búsqueda.
#
# La función crea la carpeta `data/raw` en caso de que no exista, garantizando una correcta organización de los datos sin procesar. Posteriormente, se establece la URL base de la API de OpenAlex y se configuran los parámetros de la solicitud, donde se filtran únicamente los resultados correspondientes a libros, se aplica la búsqueda por palabra clave y se limita la cantidad de resultados a 50 registros.
#
# La solicitud se realiza mediante el método GET y se incluye una validación del estado de la respuesta para asegurar que la consulta fue exitosa. Los datos obtenidos se convierten a formato JSON y se almacenan en el archivo `openalex_books.json`, utilizando codificación UTF-8 para conservar caracteres especiales y una estructura legible.
#
# Finalmente, se ejecuta la función realizando una búsqueda relacionada con *data science*, y se muestra un mensaje de confirmación indicando que el archivo fue guardado correctamente.
#
# Este proceso corresponde a la etapa de **extracción de datos** dentro del flujo ETL del proyecto.

# %%
import requests
import json
import os

def descargar_openalex(query):
    os.makedirs("data/raw", exist_ok=True)
    
    url = "https://api.openalex.org/works"
    params = {
        "filter": "type:book",
        "search": query,
        "per-page": 50
    }
    
    resp = requests.get(url, params=params)
    resp.raise_for_status()
    data = resp.json()
    
    with open("data/raw/openalex_books.json", "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    
    print("Archivo openalex_books.json guardado correctamente")

# EJECUTAR
descargar_openalex("data science")
# Out:
# Archivo openalex_books.json guardado correctamente

# %% [markdown]
# ### Conversion a csv

# %%
import pandas as pd

with open("data/raw/openalex_books.json", encoding="utf-8") as f:
    data = json.load(f)

libros = []

for item in data["results"]:
    libros.append({
        "titulo": item.get("title"),
        "anio_publicacion": item.get("publication_year"),
        "editorial": item.get("publisher"),
        "tipo": item.get("type")
    })

df = pd.DataFrame(libros)
os.makedirs("data/processed", exist_ok=True)
df.to_csv("data/processed/openalex_books.csv", index=False, encoding="utf-8")

df.head()
# Out:
#                                               titulo  anio_publicacion  \
# 0  Data Reduction and Error Analysis for the Phys...              1993
# 1                               Spatial Data Science              2023
# 2             Process Mining: Data Science in Action              2016
# 3  High-Dimensional Probability: An Introduction ...              2018
# 4  Data Science for Business: What You Need to Kn...              2013
#
#   editorial  tipo
# 0      None  book
# 1      None  book
# 2      None  book
# 3      None  book
# 4      None  book

# %% [markdown]
# ### 📙 Descarga de información desde la Crossref API
#
# Este código permite extraer información bibliográfica desde la **API de Crossref**, enfocándose en publicaciones de tipo **libro**. Crossref es una fuente confiable de metadatos académicos y editoriales, ampliamente utilizada para la identificación de publicaciones científicas mediante DOI.
#
# En primer lugar, se importan las librerías necesarias para realizar solicitudes HTTP, manipular datos en formato JSON y gestionar directorios del sistema. Luego, se define la función `descargar_crossref`, la cual no requiere parámetros, ya que realiza una consulta general de libros.
#
# La función crea la carpeta `data/raw` si no existe, asegurando una correcta organización de los datos sin procesar. Posteriormente, se establece la URL base de la API de Crossref y se configuran los parámetros de la solicitud, filtrando únicamente los resultados correspondientes a libros y limitando la cantidad de registros a 50.
#
# La solicitud se realiza mediante el método GET y la respuesta obtenida se convierte a formato JSON. Los datos se almacenan en el archivo `crossref_books.json`, utilizando codificación UTF-8 y una indentación que facilita su lectura y análisis posterior.
#
# Finalmente, se ejecuta la función y se muestra un mensaje de confirmación indicando que el archivo fue guardado correctamente.
#
# Este procedimiento corresponde a la fase de **extracción de datos** dentro del flujo ETL del proyecto.

# %%
import requests
import json
import os

def descargar_crossref():
    os.makedirs("data/raw", exist_ok=True)

    url = "https://api.crossref.org/works"
    params = {
        "filter": "type:book",
        "rows": 50
    }

    resp = requests.get(url, params=params)
    data = resp.json()

    with open("data/raw/crossref_books.json", "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

    print("Archivo crossref_books.json guardado correctamente")

descargar_crossref()
# Out:
# Archivo crossref_books.json guardado correctamente

# %% [markdown]
# ### Conversion a csv

# %%
import pandas as pd

with open("data/raw/crossref_books.json", encoding="utf-8") as f:
    data = json.load(f)

libros = []

for item in data["message"]["items"]:
    libros.append({
        "titulo": item.get("title", [""])[0],
        "anio": item.get("issued", {}).get("date-parts", [[None]])[0][0],
        "editorial": item.get("publisher"),
        "doi": item.get("DOI")
    })

df = pd.DataFrame(libros)

df.to_csv(
    "data/processed/crossref_books.csv",
    index=False,
    encoding="utf-8"
)

df.head()
# Out:
#                                               titulo  anio  \
# 0           Quantum Microscopy of Biological Systems  2015
# 1                            Excelling in the Clinic  2022
# 2              Process-Oriented Dynamic Capabilities  2014
# 3  Democracy and Judicial Reforms in South-East E...  2014
# 4                               Dichter bij diabetes  2015
#
#                            editorial                        doi
# 0  Springer International Publishing  10.1007/978-3-319-18938-3
# 1  Springer International Publishing  10.1007/978-3-030-99415-0
# 2  Springer International Publishing  10.1007/978-3-319-03251-1
# 3  Springer International Publishing  10.1007/978-3-319-04420-0
# 4            Bohn Stafleu van Loghum  10.1007/978-90-368-1053-1
